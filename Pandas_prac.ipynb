# %% [markdown]
# <a href="https://colab.research.google.com/github/DarthSC18/Python-Class/blob/main/Pandas_prac.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
sr=pd.Series([15,40,20])
print(sr[2])
# Out:
# 20

# %%
sp=pd.Series(15)
sp[4]=16
print(sp[4])
# Out:
# 16

# %%
sc=pd.Series(["Mumbai","Tokyo","New York","Vienna","Munich"],index=["India","Japan","USA","Austria","Germany"])
print(sc[-1])
# Out:
# Munich
# <ipython-input-10-3d7a41a613ec>:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(sc[-1])

# %%
df=np.genfromtxt("employee.csv",dtype=None,delimiter=',',names=True,encoding=None)

# %%
print(df[df['sal']>70000])
# Out:
# [(101, 'John', 'Doe', 75000, '15-05-1990', 'New York', 101, 'Engineering')
#  (103, 'Michael', 'Johnson', 80000, '10-02-1985', 'Chicago', 101, 'Engineering')
#  (105, 'Robert', 'Miller', 90000, '18-07-1980', 'Seattle', 102, 'Marketing')
#  (106, 'Alice', 'Jackson', 72000, '05-04-1995', 'Miami', 104, 'Finance')
#  (107, 'David', 'Anderson', 85000, '12-09-1987', 'Dallas', 101, 'Engineering')
#  (108, 'Olivia', 'Thomas', 78000, '08-12-1991', 'Houston', 103, 'Human Resources')
#  (109, 'William', 'Brown', 95000, '25-06-1982', 'Phoenix', 102, 'Marketing')
#  (111, 'James', 'Clark', 89000, '22-03-1984', 'Denver', 101, 'Engineering')
#  (112, 'Emma', 'Hall', 82000, '17-01-1994', 'Portland', 103, 'Human Resources')
#  (113, 'Christopher', 'Young', 76000, '03-07-1989', 'San Diego', 102, 'Marketing')
#  (114, 'Isabella', 'Hill', 91000, '20-04-1983', 'Orlando', 101, 'Engineering')
#  (116, 'Abigail', 'Turner', 80000, '28-02-1986', 'Austin', 103, 'Human Resources')
# ...

# %%
em=pd.read_csv("employees.csv")

# %%
em['JOB_ID'].unique()
# Out:
# array(['SH_CLERK', 'AD_ASST', 'MK_MAN', 'MK_REP', 'HR_REP', 'PR_REP',
#        'AC_MGR', 'AC_ACCOUNT', 'AD_PRES', 'AD_VP', 'IT_PROG', 'FI_MGR',
#        'FI_ACCOUNT', 'PU_MAN', 'PU_CLERK', 'ST_MAN', 'ST_CLERK'],
#       dtype=object)

# %%
print(em[em['JOB_ID']=="IT_PROG"])
# Out:
#     EMPLOYEE_ID FIRST_NAME  LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 12          103  Alexander     Hunold   AHUNOLD  590.423.4567  03-Jan-06
# 13          104      Bruce      Ernst    BERNST  590.423.4568  21-May-07
# 14          105      David     Austin   DAUSTIN  590.423.4569  25-Jun-05
# 15          106      Valli  Pataballa  VPATABAL  590.423.4560  05-Feb-06
# 16          107      Diana    Lorentz  DLORENTZ  590.423.5567  07-Feb-07
#
#      JOB_ID  SALARY COMMISSION_PCT MANAGER_ID  DEPARTMENT_ID
# 12  IT_PROG    9000             -         102             60
# 13  IT_PROG    6000             -         103             60
# 14  IT_PROG    4800             -         103             60
# 15  IT_PROG    4800             -         103             60
# 16  IT_PROG    4200             -         103             60

# %%
em[em['LAST_NAME'].duplicated()]
# Out:
# Empty DataFrame
# Columns: [EMPLOYEE_ID, FIRST_NAME, LAST_NAME, EMAIL, PHONE_NUMBER, HIRE_DATE, JOB_ID, SALARY, COMMISSION_PCT, MANAGER_ID, DEPARTMENT_ID]
# Index: []

# %%
em["EMPLOYEE_ID"].count()
# Out:
# 50

# %%
em["SALARY"].sum()
# Out:
# 309116

# %%
sem=em.sort_values(by="SALARY",ascending=True)
print(sem)
# Out:
#     EMPLOYEE_ID   FIRST_NAME    LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 41          132           TJ        Olson   TJOLSON  650.124.8234  10-Apr-07
# 45          136        Hazel   Philtanker  HPHILTAN  650.127.1634  06-Feb-08
# 37          128       Steven       Markle   SMARKLE  650.124.1434  08-Mar-08
# 44          135           Ki          Gee      KGEE  650.127.1734  12-Dec-07
# 36          127        James       Landry   JLANDRY  650.124.1334  14-Jan-07
# 49          140       Joshua        Patel    JPATEL  650.121.1834  06-Apr-06
# 40          131        James       Marlow   JAMRLOW  650.124.7234  16-Feb-05
# 28          119        Karen   Colmenares  KCOLMENA  515.127.4566  10-Aug-07
# 27          118          Guy       Himuro   GHIMURO  515.127.4565  15-Nov-06
# 0           198       Donald     OConnell  DOCONNEL  650.507.9833  21-Jun-07
# 1           199      Douglas        Grant    DGRANT  650.507.9844  13-Jan-08
# ...

# %%
em["HIRED_DATE"]=pd.to_datetime(em["HIRE_DATE"])
print(em["HIRED_DATE"])
# Out:
# 0    2007-06-21
# 1    2008-01-13
# 2    2003-09-17
# 3    2004-02-17
# 4    2005-08-17
# 5    2002-06-07
# 6    2002-06-07
# 7    2002-06-07
# 8    2002-06-07
# 9    2003-06-17
# 10   2005-09-21
# 11   2001-01-13
# 12   2006-01-03
# 13   2007-05-21
# 14   2005-06-25
# 15   2006-02-05
# 16   2007-02-07
# 17   2002-08-17
# 18   2002-08-16
# 19   2005-09-28
# 20   2005-09-30
# 21   2006-03-07
# 22   2007-12-07
# 23   2002-12-07
# 24   2003-05-18
# 25   2005-12-24
# 26   2005-07-24
# 27   2006-11-15
# 28   2007-08-10
# 29   2004-07-18
# 30   2005-04-10
# 31   2003-05-01
# 32   2005-10-10
# 33   2007-11-16
# 34   2005-07-16
# 35   2006-09-28
# 36   2007-01-14
# 37   2008-03-08
# 38   2005-08-20
# 39   2005-10-30
# 40   2005-02-16
# 41   2007-04-10
# 42   2004-06-14
# 43   2006-08-26
# 44   2007-12-12
# 45   2008-02-06
# 46   2003-07-14
# 47   2005-10-26
# 48   2006-02-12
# 49   2006-04-06
# Name: HIRED_DATE, dtype: datetime64[ns]
# ...

# %%
sem=em.sort_values(by=["HIRED_DATE"],ascending=True).head()
print(sem)
# Out:
#     EMPLOYEE_ID FIRST_NAME LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 11          102        Lex   De Haan   LDEHAAN  515.123.4569  13-Jan-01
# 5           203      Susan    Mavris   SMAVRIS  515.123.7777  07-Jun-02
# 6           204    Hermann      Baer     HBAER  515.123.8888  07-Jun-02
# 7           205    Shelley   Higgins  SHIGGINS  515.123.8080  07-Jun-02
# 8           206    William     Gietz    WGIETZ  515.123.8181  07-Jun-02
#
#         JOB_ID  SALARY COMMISSION_PCT MANAGER_ID  DEPARTMENT_ID HIRED_DATE
# 11       AD_VP   17000             -         100             90 2001-01-13
# 5       HR_REP    6500             -         101             40 2002-06-07
# 6       PR_REP   10000             -         101             70 2002-06-07
# 7       AC_MGR   12008             -         101            110 2002-06-07
# 8   AC_ACCOUNT    8300             -         205            110 2002-06-07

# %%
ec=pd.read_csv("E-Commerce.csv")

# %%
ec.head()
# Out:
#    Order_ID Product_Name     Category  Price  Quantity Customer_ID  Order_Date
# 0         1       Laptop  Electronics   1200         2        C101  01-01-2024
# 1         2   Headphones  Electronics     80         3        C102  02-01-2024
# 2         3        Chair    Furniture    150         1        C103  03-01-2024
# 3         4   Smartphone  Electronics    600         1        C104  04-01-2024
# 4         5         Desk    Furniture    200         2        C105  05-01-2024

# %%
ec.count()
# Out:
# Order_ID        30
# Product_Name    30
# Category        30
# Price           30
# Quantity        30
# Customer_ID     30
# Order_Date      30
# dtype: int64

# %%
ec["Quantity"].sum()
# Out:
# 61

# %%
avg=ec.groupby("Category")["Price"].mean().round()

# %%
avg["Accessories"]
# Out:
# 82.0

# %%
ec[ec["Price"]==ec["Price"].max()]
# Out:
#    Order_ID Product_Name     Category  Price  Quantity Customer_ID  Order_Date
# 0         1       Laptop  Electronics   1200         2        C101  01-01-2024

# %%
ec.loc[ec["Price"].idxmax()]
# Out:
# Order_ID                  1
# Product_Name         Laptop
# Category        Electronics
# Price                  1200
# Quantity                  2
# Customer_ID            C101
# Order_Date       01-01-2024
# Name: 0, dtype: object

# %%
ec["Total"]=ec["Quantity"]*ec["Price"]

# %%
ec["Total"].sort_values(ascending=False).head(5)
# Out:
# 0     2400
# 12     800
# 26     750
# 3      600
# 4      400
# Name: Total, dtype: int64

# %%
ec.groupby(["Customer_ID","Order_ID"])["Total"].sum().idxmax()
# Out:
# ('C101', 1)

# %%
ec[ec["Order_Date"]==("18-01-2024")]
# Out:
#     Order_ID Product_Name     Category  Price  Quantity Customer_ID  \
# 17        18   Sunglasses  Accessories     60         2        C118
#
#     Order_Date  Total
# 17  18-01-2024    120

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Customer_ID', 'Total')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-103-cc1533583fe5> in <cell line: 0>()
# ----> 1 ec["Customer_ID","Total"]
#
# ...

# %%
nf=pd.read_csv("Netflix_Dataset.csv")

# %%
nf.head()
# Out:
#   show_id     type         title            director  \
# 0      s1    Movie        Dangal       Nitesh Tiwari
# 1      s2  TV Show  Sacred Games      Anurag Kashyap
# 2      s3    Movie      3 Idiots     Rajkumar Hirani
# 3      s4    Movie        Lagaan  Ashutosh Gowariker
# 4      s5  TV Show   Delhi Crime        Richie Mehta
#
#                                  cast country  release_year rating   duration  \
# 0      Aamir Khan, Fatima Sana Shaikh   India          2016     UA    161 min
# 1  Saif Ali Khan, Nawazuddin Siddiqui   India          2018     UA  2 Seasons
# 2             Aamir Khan, R. Madhavan   India          2009     UA    170 min
# 3             Aamir Khan, Gracy Singh   India          2001     UA    224 min
# 4          Shefali Shah, Rasika Dugal   India          2019     UA   1 Season
#
#         genre
# 0       Drama
# 1       Crime
# 2      Comedy
# 3  Historical
# 4       Crime

# %%
nf[nf["type"]=="Movie"]["title"].unique()
# Out:
# array(['Dangal', '3 Idiots', 'Lagaan', 'Article 15', 'Taare Zameen Par',
#        'Gully Boy', 'Kabir Singh', 'Andhadhun', 'Pink', 'Queen', 'PK',
#        'Bajrangi Bhaijaan', 'Drishyam', 'Stree', 'Chhichhore', 'Super 30',
#        'Barfi', 'Piku', 'Padman', 'Badhaai Ho', 'Mission Mangal', 'Raazi',
#        'Uri', 'Kahaani', 'Special 26', 'Baby', 'Rockstar', 'Dear Zindagi',
#        'Haider', 'Bajirao Mastani', 'Sanju', 'M.S. Dhoni', 'Sultan',
#        'Highway', 'Kesari', 'Andaz Apna Apna'], dtype=object)

# %%
nf[nf["type"]=="TV Show"]["title"].unique()
# Out:
# array(['Sacred Games', 'Delhi Crime', 'Kota Factory', 'Family Man'],
#       dtype=object)

# %%
nf.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# release_year    0
# rating          0
# duration        0
# genre           0
# dtype: int64

# %%
nf["genre"].unique()
# Out:
# array(['Drama', 'Crime', 'Comedy', 'Historical', 'Social', 'Family',
#        'Musical', 'Thriller', 'Romance', 'Horror'], dtype=object)

# %%
nf["director"].unique()
# Out:
# array(['Nitesh Tiwari', 'Anurag Kashyap', 'Rajkumar Hirani',
#        'Ashutosh Gowariker', 'Richie Mehta', 'Anubhav Sinha',
#        'Raghav Subbu', 'Amole Gupte', 'Zoya Akhtar', 'Raj & DK',
#        'Sandeep Reddy Vanga', 'Sriram Raghavan',
#        'Aniruddha Roy Chowdhury', 'Vikas Bahl', 'Kabir Khan',
#        'Nishikant Kamat', 'Amar Kaushik', 'Anurag Basu', 'Shoojit Sircar',
#        'R. Balki', 'Amit Sharma', 'Jagan Shakti', 'Meghna Gulzar',
#        'Aditya Dhar', 'Sujoy Ghosh', 'Neeraj Pandey', 'Imtiaz Ali',
#        'Gauri Shinde', 'Vishal Bhardwaj', 'Sanjay Leela Bhansali',
#        'Ali Abbas Zafar', 'Anurag Singh', 'Rajkumar Santoshi'],
#       dtype=object)

# %%
nf[(nf["type"]=="Movie")&(nf["release_year"]==2019)]
# Out:
#    show_id   type           title             director  \
# 5       s6  Movie      Article 15        Anubhav Sinha
# 8       s9  Movie       Gully Boy          Zoya Akhtar
# 10     s11  Movie     Kabir Singh  Sandeep Reddy Vanga
# 18     s19  Movie      Chhichhore        Nitesh Tiwari
# 19     s20  Movie        Super 30           Vikas Bahl
# 24     s25  Movie  Mission Mangal         Jagan Shakti
# 26     s27  Movie             Uri          Aditya Dhar
# 38     s39  Movie          Kesari         Anurag Singh
#
#                                      cast country  release_year rating  \
# 5         Ayushmann Khurrana, Isha Talwar   India          2019     UA
# 8               Ranveer Singh, Alia Bhatt   India          2019     UA
# 10            Shahid Kapoor, Kiara Advani   India          2019     UA
# 18  Sushant Singh Rajput, Shraddha Kapoor   India          2019     UA
# 19          Hrithik Roshan, Mrunal Thakur   India          2019     UA
# ...

# %%
nf[(nf["type"]=="TV Show")&(nf["director"]=="Neeraj Pandey")]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, release_year, rating, duration, genre]
# Index: []

# %%
nf[(nf["type"]=="Movie")&(nf["cast"].str.contains("Akshay Kumar"))]
# Out:
#    show_id   type           title       director  \
# 22     s23  Movie          Padman       R. Balki
# 24     s25  Movie  Mission Mangal   Jagan Shakti
# 28     s29  Movie      Special 26  Neeraj Pandey
# 29     s30  Movie            Baby  Neeraj Pandey
# 38     s39  Movie          Kesari   Anurag Singh
#
#                               cast country  release_year rating duration  \
# 22      Akshay Kumar, Sonam Kapoor   India          2018     UA  140 min
# 24       Akshay Kumar, Vidya Balan   India          2019     UA  130 min
# 28    Akshay Kumar, Kajal Aggarwal   India          2013     UA  126 min
# 29     Akshay Kumar, Taapsee Pannu   India          2015     UA  155 min
# 38  Akshay Kumar, Parineeti Chopra   India          2019     UA  150 min
#
#          genre
# 22       Drama
# 24       Drama
# 28    Thriller
# 29    Thriller
# 38  Historical

# %%
rt=nf[(nf["type"]=="Movie")&(nf["rating"]=="UA")]

# %%
rt[rt["duration"].str.replace("min","").astype(int)>150]
# Out:
#    show_id   type              title               director  \
# 0       s1  Movie             Dangal          Nitesh Tiwari
# 2       s3  Movie           3 Idiots        Rajkumar Hirani
# 3       s4  Movie             Lagaan     Ashutosh Gowariker
# 7       s8  Movie   Taare Zameen Par            Amole Gupte
# 8       s9  Movie          Gully Boy            Zoya Akhtar
# 10     s11  Movie        Kabir Singh    Sandeep Reddy Vanga
# 14     s15  Movie                 PK        Rajkumar Hirani
# 15     s16  Movie  Bajrangi Bhaijaan             Kabir Khan
# 16     s17  Movie           Drishyam        Nishikant Kamat
# 19     s20  Movie           Super 30             Vikas Bahl
# 20     s21  Movie              Barfi            Anurag Basu
# 21     s22  Movie               Piku         Shoojit Sircar
# 29     s30  Movie               Baby          Neeraj Pandey
# 30     s31  Movie           Rockstar             Imtiaz Ali
# 32     s33  Movie             Haider        Vishal Bhardwaj
# ...

# %%
nf[nf["genre"].str.contains("Drama","Comedy")]
# Out:
#    show_id     type              title                 director  \
# 0       s1    Movie             Dangal            Nitesh Tiwari
# 6       s7  TV Show       Kota Factory             Raghav Subbu
# 12     s13    Movie               Pink  Aniruddha Roy Chowdhury
# 15     s16    Movie  Bajrangi Bhaijaan               Kabir Khan
# 18     s19    Movie         Chhichhore            Nitesh Tiwari
# 19     s20    Movie           Super 30               Vikas Bahl
# 21     s22    Movie               Piku           Shoojit Sircar
# 22     s23    Movie             Padman                 R. Balki
# 24     s25    Movie     Mission Mangal             Jagan Shakti
# 30     s31    Movie           Rockstar               Imtiaz Ali
# 31     s32    Movie       Dear Zindagi             Gauri Shinde
# 34     s35    Movie              Sanju          Rajkumar Hirani
# 35     s36    Movie         M.S. Dhoni            Neeraj Pandey
# 36     s37    Movie             Sultan          Ali Abbas Zafar
# ...

# %%
nf.sort_values(by=["release_year"],ascending=True).head()
# Out:
#    show_id   type             title            director  \
# 39     s40  Movie   Andaz Apna Apna   Rajkumar Santoshi
# 3       s4  Movie            Lagaan  Ashutosh Gowariker
# 7       s8  Movie  Taare Zameen Par         Amole Gupte
# 2       s3  Movie          3 Idiots     Rajkumar Hirani
# 30     s31  Movie          Rockstar          Imtiaz Ali
#
#                             cast country  release_year rating duration  \
# 39       Aamir Khan, Salman Khan   India          1994     UA  160 min
# 3        Aamir Khan, Gracy Singh   India          2001     UA  224 min
# 7    Darsheel Safary, Aamir Khan   India          2007     UA  165 min
# 2        Aamir Khan, R. Madhavan   India          2009     UA  170 min
# 30  Ranbir Kapoor, Nargis Fakhri   India          2011     UA  153 min
#
#          genre
# 39      Comedy
# 3   Historical
# 7       Family
# 2       Comedy
# 30       Drama

# %%
ty=nf.sort_values(by="type")

# %%
ty.sort_values(by="title")
# Out:
#    show_id     type              title                 director  \
# 2       s3    Movie           3 Idiots          Rajkumar Hirani
# 39     s40    Movie    Andaz Apna Apna        Rajkumar Santoshi
# 11     s12    Movie          Andhadhun          Sriram Raghavan
# 5       s6    Movie         Article 15            Anubhav Sinha
# 29     s30    Movie               Baby            Neeraj Pandey
# 23     s24    Movie         Badhaai Ho              Amit Sharma
# 33     s34    Movie    Bajirao Mastani    Sanjay Leela Bhansali
# 15     s16    Movie  Bajrangi Bhaijaan               Kabir Khan
# 20     s21    Movie              Barfi              Anurag Basu
# 18     s19    Movie         Chhichhore            Nitesh Tiwari
# 0       s1    Movie             Dangal            Nitesh Tiwari
# 31     s32    Movie       Dear Zindagi             Gauri Shinde
# 4       s5  TV Show        Delhi Crime             Richie Mehta
# 16     s17    Movie           Drishyam          Nishikant Kamat
# ...

# %%
nf.sort_values(["type","title"])
# Out:
#    show_id     type              title                 director  \
# 2       s3    Movie           3 Idiots          Rajkumar Hirani
# 39     s40    Movie    Andaz Apna Apna        Rajkumar Santoshi
# 11     s12    Movie          Andhadhun          Sriram Raghavan
# 5       s6    Movie         Article 15            Anubhav Sinha
# 29     s30    Movie               Baby            Neeraj Pandey
# 23     s24    Movie         Badhaai Ho              Amit Sharma
# 33     s34    Movie    Bajirao Mastani    Sanjay Leela Bhansali
# 15     s16    Movie  Bajrangi Bhaijaan               Kabir Khan
# 20     s21    Movie              Barfi              Anurag Basu
# 18     s19    Movie         Chhichhore            Nitesh Tiwari
# 0       s1    Movie             Dangal            Nitesh Tiwari
# 31     s32    Movie       Dear Zindagi             Gauri Shinde
# 16     s17    Movie           Drishyam          Nishikant Kamat
# 8       s9    Movie          Gully Boy              Zoya Akhtar
# ...

# %%
nf.groupby("release_year")["type"].count()
# Out:
# release_year
# 1994     1
# 2001     1
# 2007     1
# 2009     1
# 2011     1
# 2012     2
# 2013     1
# 2014     4
# 2015     5
# 2016     5
# 2018     7
# 2019    11
# Name: type, dtype: int64

# %%
nf.groupby("genre")["title"].count().head(3)
# Out:
# genre
# Comedy     6
# Crime      2
# Drama     15
# Name: title, dtype: int64

# %%
nf.groupby("director")["title"].count()
# Out:
# director
# Aditya Dhar                1
# Ali Abbas Zafar            1
# Amar Kaushik               1
# Amit Sharma                1
# Amole Gupte                1
# Aniruddha Roy Chowdhury    1
# Anubhav Sinha              1
# Anurag Basu                1
# Anurag Kashyap             1
# Anurag Singh               1
# Ashutosh Gowariker         1
# Gauri Shinde               1
# Imtiaz Ali                 2
# Jagan Shakti               1
# Kabir Khan                 1
# Meghna Gulzar              1
# Neeraj Pandey              3
# Nishikant Kamat            1
# Nitesh Tiwari              2
# R. Balki                   1
# Raghav Subbu               1
# Raj & DK                   1
# Rajkumar Hirani            3
# Rajkumar Santoshi          1
# Richie Mehta               1
# Sandeep Reddy Vanga        1
# Sanjay Leela Bhansali      1
# Shoojit Sircar             1
# Sriram Raghavan            1
# Sujoy Ghosh                1
# Vikas Bahl                 2
# ...

# %%
nf.groupby("rating")["title"].count()
# Out:
# rating
# UA    40
# Name: title, dtype: int64

# %%
tm=nf[nf["title"].str.contains("Man")].count()

# %%
nf[nf["title"].str.contains("Love","Life")].count()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# release_year    0
# rating          0
# duration        0
# genre           0
# dtype: int64

# %%
nf.groupby("cast")["title"].count()
# Out:
# cast
# Aamir Khan, Anushka Sharma               1
# Aamir Khan, Fatima Sana Shaikh           1
# Aamir Khan, Gracy Singh                  1
# Aamir Khan, R. Madhavan                  1
# Aamir Khan, Salman Khan                  1
# Ajay Devgn, Tabu                         1
# Akshay Kumar, Kajal Aggarwal             1
# Akshay Kumar, Parineeti Chopra           1
# Akshay Kumar, Sonam Kapoor               1
# Akshay Kumar, Taapsee Pannu              1
# Akshay Kumar, Vidya Balan                1
# Alia Bhatt, Randeep Hooda                1
# Alia Bhatt, Shah Rukh Khan               1
# Alia Bhatt, Vicky Kaushal                1
# Amitabh Bachchan, Deepika Padukone       1
# Amitabh Bachchan, Taapsee Pannu          1
# Ayushmann Khurrana, Isha Talwar          1
# Ayushmann Khurrana, Neena Gupta          1
# Ayushmann Khurrana, Tabu                 1
# Darsheel Safary, Aamir Khan              1
# Hrithik Roshan, Mrunal Thakur            1
# Kangana Ranaut, Rajkummar Rao            1
# ...

# %%
nf[nf["director"].str.contains("Rajkumar Hirani","Anurag Kashyap")]
# Out:
#    show_id   type     title         director                         cast  \
# 2       s3  Movie  3 Idiots  Rajkumar Hirani      Aamir Khan, R. Madhavan
# 14     s15  Movie        PK  Rajkumar Hirani   Aamir Khan, Anushka Sharma
# 34     s35  Movie     Sanju  Rajkumar Hirani  Ranbir Kapoor, Paresh Rawal
#
#    country  release_year rating duration   genre
# 2    India          2009     UA  170 min  Comedy
# 14   India          2014     UA  153 min  Comedy
# 34   India          2018     UA  161 min   Drama

# %%
nf[nf.duplicated()]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, release_year, rating, duration, genre]
# Index: []
